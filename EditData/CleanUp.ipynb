# %% [markdown]
# DATA Breakdown: PS4 Games
# https://www.kaggle.com/datasets/shivamb/all-playstation-4-games?resource=download

# %% [markdown]
# ### Introduction:

# %%
#General import statements
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MultiLabelBinarizer

# %%
#Read in the csv, and look at the columns, and observe what the columns alone might tell us and how it seems important
df = pd.read_csv("data/playstation_4_games.csv")

df.columns.unique()
# Out:
# Index(['ID', 'GamePSID', 'GameName', 'Publisher', 'ReleaseYear', 'ReleaseDate',
#        'Developer', 'Genre', 'Features', 'Size', 'Medium', 'Hardware',
#        'CompletionTime(Hours)', 'is_Digital_game', 'is_Physical_game',
#        'OfficialWebsite'],
#       dtype='object')

# %%
df.head(10)
#Looking at these columns, I can infer that:
#ID is just referencing the order for the csv and not relevant for the end data, just for data manipulation
#GamePSID might be useful to keep if it seems that it has any relation to it's ID in the PS store?
#GameName is obviously important to know what title we're refrencing
#Publisher looks to be important if we want to recommend games with the same publisher
#ReleaseYear doesn't seem super important, but maybe if someone only buys older or newer games? 
#ReleaseDate is too specific, might interrupt data, it's probably realistic to assume that someone would buy a game based off a month or day, but year is okay.
#Genre, probably the most important metric for our data to evaluate
#Features, probably not super important, the first few entries seem to show us that it might be good, if people only want a game if it's within PS Now data or PS Plus
#Size, size of the same, probably not an important metric, but it could be?
#Medium, could be important if some people only buy digital only or avoid games that are digital only, probably not the best final metric but not a bad metric in general
#Hardware, could be useful, but maybe not? Will probably drop to avoid overfitting
#ComletionTime(Hours), a decent metric, maybe someone only likes indie games...Might be too specific, candidate for removal
#is_Digital_game, will have to observe if it produces better data than just Medium
#is_Physical_game, see above
#OfficialWebstie, tells us the website. Far from a useful metric. Will drop
# Out:
#    ID  GamePSID                 GameName            Publisher  ReleaseYear  \
# 0   1      3045          Q*Bert Rebooted     LOOT Interactive       2015.0
# 1   2      3051     Q*Bert Rebooted (EU)     LOOT Interactive       2015.0
# 2   3      6703               Q.U.B.E. 2  Trapped Nerve Games       2018.0
# 3   4      3403  Q.U.B.E. Director's Cut         GRIP Digital       2015.0
# 4   5     13176              Quake (PS4)   Bethesda Softworks       2021.0
# 5   6     -2913          Quantic Pinball                  NaN          NaN
# 6   7     -4119            Quantum Error                  NaN          NaN
# 7   8     -4106           Quantum League                  NaN          NaN
# 8   9     12156          Quantum Replica                PQube       2021.0
# 9  10     12157     Quantum Replica (EU)                PQube       2021.0
#
#   ReleaseDate                                     Developer  \
# 0  2015-02-17                                   Gonzo Games
# 1  2015-07-22                              LOOT Interactive
# 2  2018-03-13                                   Toxic Games
# 3  2015-07-21                                   Toxic Games
# 4  2021-08-19  MachineGames, Nightdive Studios, id Software
# 5         NaN                                           NaN
# 6         NaN                                           NaN
# 7         NaN                                           NaN
# 8  2021-05-14                                  ON3D Studios
# 9  2021-05-14                                  ON3D Studios
#
#                   Genre         Features     Size                Medium  \
# 0                Action  PS Plus, PS Now   109.00                   NaN
# 1                Action           PS Now   127.00          Digital only
# 2    Puzzle, Platformer              NaN  2682.88          Digital only
# 3    Puzzle, Platformer          PS Plus  1945.60          Digital only
# 4  First Person Shooter              NaN      NaN  Physical and Digital
# 5                   NaN              NaN      NaN                   NaN
# 6                   NaN              NaN      NaN                   NaN
# 7                   NaN              NaN      NaN                   NaN
# 8               Stealth              NaN      NaN          Digital only
# 9               Stealth              NaN      NaN          Digital only
#
#   Hardware CompletionTime(Hours)  is_Digital_game  is_Physical_game  \
# 0      NaN                   NaN                0                 0
# 1      NaN                   NaN                0                 0
# 2      NaN                   NaN                0                 0
# 3      NaN                   3-4                0                 0
# 4      NaN                   NaN                0                 0
# 5      NaN                   NaN                0                 0
# 6      NaN                   NaN                0                 0
# 7      NaN                   NaN                0                 0
# 8  PS4 Pro                   NaN                0                 0
# 9  PS4 Pro                   NaN                0                 0
#
#                             OfficialWebsite
# 0  http://www.sidelineamusements.com/qbert/
# 1  http://www.sidelineamusements.com/qbert/
# 2                     http://qube-game.com/
# 3                     http://qube-game.com/
# 4        https://bethesda.net/en/game/quake
# 5        https://bethesda.net/en/game/quake
# 6               https://quantumerror.games/
# 7               https://quantum-league.com/
# 8       http://pqube.co.uk/quantum-replica/
# 9       http://pqube.co.uk/quantum-replica/

# %%
df.info() #Doesn't show much, but nice to see non-null counts. At glance it seems HardWare, Features and CompletionTime(Hours) might be too small to keep. 
df.describe(include='all') 
#I see non-unique game names, 15 to be exact, will inspect these first and remove duplicate data
#1723 Unique Publishers, small number, but, seems very good to have for reccomendations!
#482 Genres! That's a lot, I'll take a look to see if any of these genres are duplicated as well. (i.e. any typos or spelling errors
#Why is ReleaseYear a float? Change to int.
#Those are the big observations for now.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9686 entries, 0 to 9685
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     9686 non-null   int64
#  1   GamePSID               9686 non-null   int64
#  2   GameName               9686 non-null   object
#  3   Publisher              8964 non-null   object
#  4   ReleaseYear            8952 non-null   float64
#  5   ReleaseDate            8952 non-null   object
#  6   Developer              8987 non-null   object
#  7   Genre                  8898 non-null   object
#  8   Features               1749 non-null   object
#  9   Size                   7666 non-null   float64
#  10  Medium                 8937 non-null   object
#  11  Hardware               1512 non-null   object
#  12  CompletionTime(Hours)  2230 non-null   object
#  13  is_Digital_game        9686 non-null   int64
#  14  is_Physical_game       9686 non-null   int64
#  15  OfficialWebsite        8089 non-null   object
# dtypes: float64(2), int64(4), object(10)
# memory usage: 1.2+ MB
#                  ID      GamePSID                                    GameName  \
# count   9686.000000   9686.000000                                        9686
# unique          NaN           NaN                                        9671
# top             NaN           NaN  Prince of Persia: The Sands of Time Remake
# freq            NaN           NaN                                           3
# mean    4843.500000   7450.627813                                         NaN
# std     2796.251688   4434.041993                                         NaN
# min        1.000000  -5590.000000                                         NaN
# 25%     2422.250000   5108.250000                                         NaN
# 50%     4843.500000   7972.500000                                         NaN
# 75%     7264.750000  10749.750000                                         NaN
# max     9686.000000  14229.000000                                         NaN
#
#            Publisher  ReleaseYear ReleaseDate Developer       Genre  \
# count           8964  8952.000000        8952      8987        8898
# unique          1723          NaN        1659      3110         482
# top     eastasiasoft          NaN  2021-09-30   Hamster  Platformer
# freq             503          NaN          35       124         736
# mean             NaN  2018.515304         NaN       NaN         NaN
# std              NaN     2.014025         NaN       NaN         NaN
# min              NaN  2009.000000         NaN       NaN         NaN
# 25%              NaN  2017.000000         NaN       NaN         NaN
# 50%              NaN  2019.000000         NaN       NaN         NaN
# 75%              NaN  2020.000000         NaN       NaN         NaN
# max              NaN  2022.000000         NaN       NaN         NaN
#
#          Features          Size        Medium Hardware CompletionTime(Hours)  \
# count        1749  7.666000e+03          8937     1512                  2230
# unique         25           NaN             3       33                    23
# top     Cross-Buy           NaN  Digital only  PS4 Pro                   0-1
# freq          775           NaN          5927      748                   802
# mean          NaN  5.207188e+03           NaN      NaN                   NaN
# std           NaN  1.880542e+04           NaN      NaN                   NaN
# min           NaN  1.100000e+01           NaN      NaN                   NaN
# 25%           NaN  3.922500e+02           NaN      NaN                   NaN
# 50%           NaN  1.392640e+03           NaN      NaN                   NaN
# 75%           NaN  4.710400e+03           NaN      NaN                   NaN
# max           NaN  1.002496e+06           NaN      NaN                   NaN
#
#         is_Digital_game  is_Physical_game  \
# count            9686.0            9686.0
# unique              NaN               NaN
# top                 NaN               NaN
# freq                NaN               NaN
# mean                0.0               0.0
# std                 0.0               0.0
# min                 0.0               0.0
# 25%                 0.0               0.0
# 50%                 0.0               0.0
# 75%                 0.0               0.0
# max                 0.0               0.0
#
#                                           OfficialWebsite
# count                                                8089
# unique                                               6126
# top     http://www.hamster.co.jp/american_hamster/arca...
# freq                                                   17
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# #### Looking at Duplicate Titles:

# %%
duplicate_df = df[df['GameName'].duplicated()]

duplicate_df.count()

duplicate_df.head(15)
# Out:
#         ID  GamePSID                                    GameName  \
# 868    869     13856                       Riders Republic (PS4)
# 987    988     12823                               Rogue Wizards
# 988    989     12824                               Rogue Wizards
# 2463  2464     13199                                   OctaFight
# 2563  2564     13208     One-Eyed Lee and the Dinner Party (PS4)
# 3048  3049     11907  Prince of Persia: The Sands of Time Remake
# 3049  3050     11908  Prince of Persia: The Sands of Time Remake
# 4361  4362     12891                                 Slide Stars
# 4538  4539     12889                         Speed 3: Grand Prix
# 4539  4540     11003                         Speed 3: Grand Prix
# 6442  6443      6384                                    Gunhouse
# 7420  7421     10969                           Lust for Darkness
# 7826  7827     10231                             Conan Chop Chop
# 7917  7918     13880                             Crazy Athletics
# 9685  9686     14118                          Klang 2 (JP) (PS4)
#
#                                             Publisher  ReleaseYear  \
# 868                                           Ubisoft       2021.0
# 987                                 Spellbind Studios          NaN
# 988                                 Spellbind Studios          NaN
# 2463                                Ghislain Avrillon       2021.0
# 2563                                  Ratalaika Games       2021.0
# 3048                                          Ubisoft          NaN
# 3049                                          Ubisoft          NaN
# 4361                                              NaN          NaN
# 4538                                              NaN          NaN
# 4539  Lion Castle Entertainment, GS2 Games, Mindscape       2020.0
# 6442                                  Necrosoft Games       2017.0
# 7420                                        SimFabric       2020.0
# 7826                                           Funcom       2022.0
# 7917                                        Crazysoft       2021.0
# 9685                                  Ratalaika Games       2021.0
#
#      ReleaseDate                     Developer  \
# 868   2021-10-28                Ubisoft Annecy
# 987          NaN             Spellbind Studios
# 988          NaN             Spellbind Studios
# 2463  2021-08-30          Pixel Almost Perfect
# 2563  2021-08-27               DarkChibiShadow
# 3048         NaN  Ubisoft Pune, Ubisoft Mumbai
# 3049         NaN  Ubisoft Pune, Ubisoft Mumbai
# 4361         NaN              Triangle Studios
# 4538         NaN     Lion Castle Entertainment
# 4539  2020-11-10     Lion Castle Entertainment
# 6442  2017-12-19               Necrosoft Games
# 7420  2020-10-23          Movie Games Lunarium
# 7826  2022-02-08                Mighty Kingdom
# 7917  2021-12-03                     Crazysoft
# 9685  2021-11-17                   Tinimations
#
#                                       Genre   Features     Size  \
# 868   Sports, Cycling, Skiing, Snowboarding  Cross-Buy      NaN
# 987     Roguelite, Role Playing, Turn Based        NaN      NaN
# 988     Roguelite, Role Playing, Turn Based        NaN      NaN
# 2463                                 Action        NaN      NaN
# 2563                           Visual Novel  Cross-Buy      NaN
# 3048                       Action-Adventure        NaN      NaN
# 3049                       Action-Adventure        NaN      NaN
# 4361                             Platformer        NaN      NaN
# 4538              Automobile, Arcade Racing        NaN      NaN
# 4539              Automobile, Arcade Racing        NaN  4730.88
# 6442                  Puzzle, Tower Defence    PS Plus   258.00
# 7420                              Adventure        NaN  8847.36
# 7826    Roguelite, Action-RPG, Role Playing        NaN      NaN
# 7917                                    NaN        NaN      NaN
# 9685                                    NaN  Cross-Buy      NaN
#
#                     Medium Hardware CompletionTime(Hours)  is_Digital_game  \
# 868   Physical and Digital  PS4 Pro                   NaN                0
# 987           Digital only      NaN                   NaN                0
# 988           Digital only      NaN                   NaN                0
# 2463          Digital only      NaN                   NaN                0
# 2563          Digital only      NaN                   0-1                0
# 3048  Physical and Digital      NaN                   NaN                0
# 3049  Physical and Digital      NaN                   NaN                0
# 4361          Digital only      NaN                   NaN                0
# 4538          Digital only      NaN                   NaN                0
# 4539  Physical and Digital      NaN                   NaN                0
# 6442  Physical and Digital      NaN                   NaN                0
# 7420          Digital only      NaN                   NaN                0
# 7826          Digital only      NaN                   NaN                0
# 7917          Digital only      NaN                   NaN                0
# 9685          Digital only      NaN                   NaN                0
#
#       is_Physical_game                                    OfficialWebsite
# 868                  0  https://www.ubisoft.com/en-us/game/riders-repu...
# 987                  0                           http://roguewizards.com/
# 988                  0                           http://roguewizards.com/
# 2463                 0                              http://octafight.com/
# 2563                 0  https://www.ratalaikagames.com/games/oneeyedle...
# 3048                 0  https://www.ubisoft.com/en-us/game/prince-of-p...
# 3049                 0  https://www.ubisoft.com/en-us/game/prince-of-p...
# 4361                 0                                                NaN
# 4538                 0                                                NaN
# 4539                 0            https://gs2games.com/speed-3-grand-prix
# 6442                 0               https://necrosoftgames.com/gunhouse/
# 7420                 0     https://moviegames.pl/en/lust-for-darkness-en/
# 7826                 0                     https://www.conanchopchop.com/
# 7917                 0  https://www.crazysoft.gr/all/crazy_athletics_s...
# 9685                 0                                                NaN

# %%
#Here I'm looking at each individual piece of data from the above list from duplicates, looking at each title to determine which to drop, or if they're valid to keep as duplicates (I doubt it)

#df[df['GameName'] == "Riders Republic (PS4)"].head() #DROP ID = 868, both safe
df[df['GameName'] == "Rogue Wizards"].head() #DROP ID = 988 and 989, only 987 has a Release Date so keep
#df[df['GameName'] == "OctaFight"].head() #Either are fine to keep, they share the exact same data, DROP ID = 2464
#df[df['GameName'] == "One-Eyed Lee and the Dinner Party (PS4)"].head() #Same as above, DROP ID = 2564, both entries have exact data
#df[df['GameName'] == "Prince of Persia: The Sands of Time Remake"].head() #DROP ID = 11907 and 11908 for sake of the same issue above. Potentially drop 11906 also, for the separate csv that has only games that are released
#df[df['GameName'] == "Slide Stars"].head() #DROP ID = 4362, far less data than that of 4361
#df[df['GameName'] == "Speed 3: Grand Prix"].head() #DROP ID = 4538 and 4539, these two do not have release data or a publisher, and thus should not skew data so remove
#df[df['GameName'] == "Gunhouse"].head() #DROP ID = 6442 Has no info, looks to be for VR only? Keep 6443
#df[df['GameName'] == "Lust for Darkness"].head() #DROP ID = 7420, has no info for anything other than name and website. KEEP 7421
#df[df['GameName'] == "Conan Chop Chop"].head() #These are exactly the same, thus DROP ID = 10231
#df[df['GameName'] == "Crazy Athletics"].head() #DROP ID = 7918, Only difference is no genre
#df[df['GameName'] == "Klang 2 (JP) (PS4)"].head() #DROP ID = 7041,HOWEVER, No Genre, Probably won't keep either

drop_ids = [868, 988, 989, 2464, 2564, 11907, 11908, 4362, 4538, 4539, 6442, 7420, 10231, 7918, 7041]
#Observation, the titles with a negative valued GamePSID seems to be the ones with absolutely no data in it other than title, will test this in the next box
#Also, adding ids to drop within a list, to make it easier
df[df['GameName'] == "Rogue Wizards"].head()
# Out:
#       ID  GamePSID       GameName          Publisher  ReleaseYear ReleaseDate  \
# 986  987     12745  Rogue Wizards  Spellbind Studios       2021.0  2021-07-21
# 987  988     12823  Rogue Wizards  Spellbind Studios          NaN         NaN
# 988  989     12824  Rogue Wizards  Spellbind Studios          NaN         NaN
#
#              Developer                                Genre Features  Size  \
# 986  Spellbind Studios  Roguelite, Role Playing, Turn Based      NaN   NaN
# 987  Spellbind Studios  Roguelite, Role Playing, Turn Based      NaN   NaN
# 988  Spellbind Studios  Roguelite, Role Playing, Turn Based      NaN   NaN
#
#            Medium Hardware CompletionTime(Hours)  is_Digital_game  \
# 986  Digital only      NaN                   NaN                0
# 987  Digital only      NaN                   NaN                0
# 988  Digital only      NaN                   NaN                0
#
#      is_Physical_game           OfficialWebsite
# 986                 0  http://roguewizards.com/
# 987                 0  http://roguewizards.com/
# 988                 0  http://roguewizards.com/

# %%
test_df = df[df['GamePSID'] < 0]
test_df.count()
#This seems that there are 0 games with a genre, developer, or publisher mentioned
# Out:
# ID                       699
# GamePSID                 699
# GameName                 699
# Publisher                  0
# ReleaseYear                0
# ReleaseDate                0
# Developer                  0
# Genre                      0
# Features                   0
# Size                       0
# Medium                     0
# Hardware                  14
# CompletionTime(Hours)      0
# is_Digital_game          699
# is_Physical_game         699
# OfficialWebsite          653
# dtype: int64

# %%
test_df['Genre'].unique()
#I believe that this is safe to conclude, it's also safe to drop any game with a GamePSID < 0 as none of the entries in that category have a value other than NaN
# Out:
# array([nan], dtype=object)

# %%
# Non-Null Count Bar Chart (Original Data)
# Visualize Our Purpose in Feature Dropping
plt.figure()
df.isnull().sum().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Missing Values (Non-Null Counts)')
plt.xlabel('Features (Column Names)')
plt.ylabel('Number of Missing Values')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Cleaning Up Our Data:

# %%
#Drop the data from our original dataframe who has a GamePSID value <=0 (or rather, keep GamePSID values that are > 0),
dropped_data_df = df[df['GamePSID'] > 0]
dropped_data_df = dropped_data_df[~dropped_data_df['ID'].isin(drop_ids)]

#Drop columns that dont seem to impact as much
dropped_data_df = dropped_data_df.drop('OfficialWebsite', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('ReleaseDate', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('Features', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('Hardware', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('CompletionTime(Hours)', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('Size', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('is_Digital_game', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('is_Physical_game', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.drop('GamePSID', axis = 1, inplace = False)
dropped_data_df = dropped_data_df.dropna(subset = ['Genre'])                                        #Willing to remove this line if necessary

dropped_data_df.info()
dropped_data_df.describe(include='all')
#Uh-Oh, there seems to be a couple of areas that still have data missing for Genre. 87 entries do not have any genre, but now we safely parsed and cleaned duplicate GameNames, we will probably purge this as well
#I also decided to remove the columns of Features, Hardware and CompletionTime because there were too little non-null entries, it may impact training data negatively. [Counts for them: 1746, 1497, 2229. Respectively]
#This means that, only [19.45%, 16.68%, and 24.83%] of the remaining data had information in their respective column. This may sway training data, and also does not provide a lot of information
#I chose to also drop ReleaseDate as Release Year seems to be a better metric that wont impact data as opposed to the full Date, I dropped OfficialWebsite because it had no impact on our data
#I also chose to drop Size, as I felt it wasn't very relevant for most people. The last columns, i.e. is_Digital_game and is_Physical_game both were dropped as well because they were empty columns
#I also believe that GamePSID no longer has any bearing on our data, so I dropped it too. 
#I also decided to drop any data that's missing the Genre, as this will be one of our main categories we look at. 
#I will create an optional csv we can use that drops the Medium category, but for now, I will keep it.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8890 entries, 0 to 9684
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           8890 non-null   int64
#  1   GameName     8890 non-null   object
#  2   Publisher    8871 non-null   object
#  3   ReleaseYear  8867 non-null   float64
#  4   Developer    8890 non-null   object
#  5   Genre        8890 non-null   object
#  6   Medium       8840 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 555.6+ KB
#                  ID                                    GameName     Publisher  \
# count   8890.000000                                        8890          8871
# unique          NaN                                        8887          1713
# top             NaN  Prince of Persia: The Sands of Time Remake  eastasiasoft
# freq            NaN                                           3           496
# mean    4865.638245                                         NaN           NaN
# std     2787.718850                                         NaN           NaN
# min        1.000000                                         NaN           NaN
# 25%     2474.250000                                         NaN           NaN
# 50%     4863.500000                                         NaN           NaN
# 75%     7278.750000                                         NaN           NaN
# max     9685.000000                                         NaN           NaN
#
#         ReleaseYear Developer       Genre        Medium
# count   8867.000000      8890        8890          8840
# unique          NaN      3090         482             3
# top             NaN   Hamster  Platformer  Digital only
# freq            NaN       124         735          5853
# mean    2018.491485       NaN         NaN           NaN
# std        2.008838       NaN         NaN           NaN
# min     2009.000000       NaN         NaN           NaN
# 25%     2017.000000       NaN         NaN           NaN
# 50%     2019.000000       NaN         NaN           NaN
# 75%     2020.000000       NaN         NaN           NaN
# max     2022.000000       NaN         NaN           NaN

# %% [markdown]
# Looking at Genres:

# %%
#dropped_data_df['Genre'] = dropped_data_df['Genre'].str.strip().str.lower()
#dropped_data_df['Genre'].nunique()
#Running the above code, shows that there are no issues of any genres being counted as a new genre in the case of case sensitivity or have an extra space in the entry
#Nothing to drop, will take a look at the counts and such
dropped_data_df['Genre'].value_counts().sort_index()
#This shows us that the "unique"-ness of the data isn't very true, as some of these entries have multiple genres implemented into them.
# Out:
# Genre
# Action                                             559
# Action Horror                                       13
# Action Horror, Action-Adventure                      1
# Action Horror, First Person Shooter                 17
# Action Horror, First Person Shooter, Platformer      1
#                                                   ...
# Vehicular Combat                                     1
# Vehicular Combat, Shoot 'em up                       1
# Visual Novel                                       393
# Volleyball, Sports                                   4
# Volleyball, Sports, Football, Tennis                 2
# Name: count, Length: 482, dtype: int64

# %%
#Let's try and find the truly unique genres here by finding the entries that don't have a separator, or comma
unique_genres = dropped_data_df[dropped_data_df['Genre'].str.contains(",", na=False) == False]


print(unique_genres['Genre'].describe())
#This narrows us down to 45 unique genres! That's much more realistic, still a large number though.
print(unique_genres['Genre'].unique())
#These all seem to be very unique! No overlap in genres that'd be due to a typo. 
#I haven't, but we could also use alias mapping to reduce the genre number to get even less columns here, but I think it's fine? They seem unique enough, but I could see potential overlap

unique_genres['Genre'] = unique_genres['Genre'].apply(lambda x: [genre.strip() for genre in x.split(',')])

unique_genres.head(15)
# Out:
# count           5368
# unique            45
# top       Platformer
# freq             735
# Name: Genre, dtype: object
# ['Action' 'First Person Shooter' 'Stealth' 'Platformer' 'Action-Adventure'
#  'Party' 'Educational & Trivia' 'Collectable Card Game' "Shoot 'em up"
#  'Puzzle' 'Adventure' 'Fighting' "Beat 'em up" 'Hack & Slash' 'Strategy'
#  'Sports' 'Visual Novel' 'Music' 'Simulation' 'Run & Gun'
#  'Survival Horror' 'Roguelite' 'Action Horror' 'Management'
#  'Third Person Shooter' 'Arcade Racing' 'Dungeon Crawler' 'Card & Board'
#  'Simulation Racing' 'Tower Defence' 'Sandbox' 'Collection' 'Casino'
#  'Point & Click' 'Survival' 'Pinball' 'Role Playing' 'MOBA' 'Dance' 'Mech'
#  'Battle Royale' 'On Rails' 'Metroidvania' 'Open World' 'Vehicular Combat']
# C:\Users\mbuck\AppData\Local\Temp\ipykernel_22756\1345443952.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_genres['Genre'] = unique_genres['Genre'].apply(lambda x: [genre.strip() for genre in x.split(',')])
#     ID                                           GameName  \
# 0    1                                    Q*Bert Rebooted
# 1    2                               Q*Bert Rebooted (EU)
# 4    5                                        Quake (PS4)
# 8    9                                    Quantum Replica
# 9   10                               Quantum Replica (EU)
# 12  13                                      Qubit's Quest
# 16  17             QUByte Classics - The Immortal by PIKO
# 24  25                                           Quiplash
# 25  26  Quiplash 2 Interlashional: The Say Anything Pa...
# 26  27                                Quiz Night Tonight!
# 27  28                              Qurare: Magic Library
# 28  29                       Qurare: Magic Library (Asia)
# 29  30                                       Q-YO Blaster
# 30  31                                  Q-YO Blaster (EU)
# 31  32                                        Waddle Home
#
#                         Publisher  ReleaseYear  \
# 0                LOOT Interactive       2015.0
# 1                LOOT Interactive       2015.0
# 4              Bethesda Softworks       2021.0
# 8                           PQube       2021.0
# 9                           PQube       2021.0
# 12  Performance Designed Products       2019.0
# 16             QUByte Interactive       2021.0
# 24                  Jackbox Games       2015.0
# 25                  Jackbox Games       2020.0
# 26                      Mardonpol       2017.0
# 27             Smilegate Megaport       2016.0
# 28             Smilegate Megaport       2016.0
# 29          Forever Entertainment       2021.0
# 30          Forever Entertainment       2021.0
# 31                       Archiact       2016.0
#
#                                        Developer                    Genre  \
# 0                                    Gonzo Games                 [Action]
# 1                               LOOT Interactive                 [Action]
# 4   MachineGames, Nightdive Studios, id Software   [First Person Shooter]
# 8                                   ON3D Studios                [Stealth]
# 9                                   ON3D Studios                [Stealth]
# 12                        Two Okes Entertainment             [Platformer]
# 16                              Piko Interactive       [Action-Adventure]
# 24                                 Jackbox Games                  [Party]
# 25                                 Jackbox Games                  [Party]
# 26                                     Mardonpol   [Educational & Trivia]
# 27                                     iO Studio  [Collectable Card Game]
# 28                                     iO Studio  [Collectable Card Game]
# 29   Team Robot Black Hat, Forever Entertainment           [Shoot 'em up]
# 30   Team Robot Black Hat, Forever Entertainment           [Shoot 'em up]
# 31                                      Archiact                 [Puzzle]
#
#                   Medium
# 0                    NaN
# 1           Digital only
# 4   Physical and Digital
# 8           Digital only
# 9           Digital only
# 12  Physical and Digital
# 16          Digital only
# 24          Digital only
# 25          Digital only
# 26          Digital only
# 27          Digital only
# 28          Digital only
# 29          Digital only
# 30          Digital only
# 31          Digital only

# %%
#Instead of importing OneHotEncoding, I came in to a lot of errors and complications that affected how the dataset would look like. Further research showed me that MultiLabelBinarizer
# was a better way to approach this problem. So, to split the data I imported the MultiLabelBinarizer instead. This is mainly because OneHotEncoding is meant for encoding features into exactly one category.
# Because, I did not want this for our data, I preferred that we instead were to allow our games to have multiple categories (Genres, in our case) attributed to them. Thus, I ended up on using MultiLabelBinarizer

#Here I edit the Genre column of our most up to date dataframe, here I converted the lists to strings, then removed the leading spaces and separated the strings by columns
dropped_data_df['Genre'] = dropped_data_df['Genre'].apply(lambda x: x if isinstance(x, list) else [g.strip() for g in x.split(',')])

mlb = MultiLabelBinarizer()

genres = pd.DataFrame(mlb.fit_transform(dropped_data_df['Genre']), columns=mlb.classes_,index=dropped_data_df.index)

final_df = pd.concat([dropped_data_df, genres], axis=1)

print(final_df[final_df['GameName'] == 'Rogue Wizards'] )
final_df.info()
# Out:
#       ID       GameName          Publisher  ReleaseYear          Developer  \
# 986  987  Rogue Wizards  Spellbind Studios       2021.0  Spellbind Studios
#
#                                      Genre        Medium  Action  \
# 986  [Roguelite, Role Playing, Turn Based]  Digital only       0
#
#      Action Horror  Action-Adventure  ...  Survival Horror  Table Tennis  \
# 986              0                 0  ...                0             0
#
#      Tennis  Third Person Shooter  Tower Defence  Turn Based  \
# 986       0                     0              0           1
#
#      Vehicular Combat  Visual Novel  Volleyball  Wrestling
# 986                 0             0           0          0
#
# [1 rows x 92 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 8890 entries, 0 to 9684
# Data columns (total 92 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     8890 non-null   int64
#  1   GameName               8890 non-null   object
#  2   Publisher              8871 non-null   object
#  3   ReleaseYear            8867 non-null   float64
#  4   Developer              8890 non-null   object
#  5   Genre                  8890 non-null   object
#  6   Medium                 8840 non-null   object
#  7   Action                 8890 non-null   int64
#  8   Action Horror          8890 non-null   int64
#  9   Action-Adventure       8890 non-null   int64
#  10  Action-RPG             8890 non-null   int64
#  11  Adventure              8890 non-null   int64
#  12  Aerial                 8890 non-null   int64
#  13  American Football      8890 non-null   int64
#  14  Arcade Racing          8890 non-null   int64
#  15  Australian Football    8890 non-null   int64
#  16  Automobile             8890 non-null   int64
#  17  Baseball               8890 non-null   int64
#  18  Basketball             8890 non-null   int64
#  19  Battle Royale          8890 non-null   int64
#  20  Beat 'em up            8890 non-null   int64
#  21  Bowling                8890 non-null   int64
#  22  Boxing                 8890 non-null   int64
#  23  Bullfighting           8890 non-null   int64
#  24  Card & Board           8890 non-null   int64
#  25  Casino                 8890 non-null   int64
#  26  Collectable Card Game  8890 non-null   int64
#  27  Collection             8890 non-null   int64
#  28  Cricket                8890 non-null   int64
#  29  Cue Sports             8890 non-null   int64
#  30  Cycling                8890 non-null   int64
#  31  Dance                  8890 non-null   int64
#  32  Darts                  8890 non-null   int64
#  33  Dodgeball              8890 non-null   int64
#  34  Dungeon Crawler        8890 non-null   int64
#  35  Educational & Trivia   8890 non-null   int64
#  36  Equestrian Sports      8890 non-null   int64
#  37  Fighting               8890 non-null   int64
#  38  First Person Shooter   8890 non-null   int64
#  39  Fishing                8890 non-null   int64
#  40  Football               8890 non-null   int64
#  41  Golf                   8890 non-null   int64
#  42  Hack & Slash           8890 non-null   int64
#  43  Handball               8890 non-null   int64
#  44  Health & Fitness       8890 non-null   int64
#  45  Hockey                 8890 non-null   int64
#  46  Hunting                8890 non-null   int64
#  47  Lacrosse               8890 non-null   int64
#  48  MMO                    8890 non-null   int64
#  49  MOBA                   8890 non-null   int64
#  50  Management             8890 non-null   int64
#  51  Mech                   8890 non-null   int64
#  52  Metroidvania           8890 non-null   int64
#  53  Mixed Martial Arts     8890 non-null   int64
#  54  Motocross              8890 non-null   int64
#  55  Music                  8890 non-null   int64
#  56  Naval                  8890 non-null   int64
#  57  On Rails               8890 non-null   int64
#  58  Open World             8890 non-null   int64
#  59  Party                  8890 non-null   int64
#  60  Pinball                8890 non-null   int64
#  61  Platformer             8890 non-null   int64
#  62  Point & Click          8890 non-null   int64
#  63  Puzzle                 8890 non-null   int64
#  64  Real Time              8890 non-null   int64
#  65  Roguelite              8890 non-null   int64
#  66  Role Playing           8890 non-null   int64
#  67  Rugby                  8890 non-null   int64
#  68  Run & Gun              8890 non-null   int64
#  69  Sandbox                8890 non-null   int64
#  70  Shoot 'em up           8890 non-null   int64
#  71  Simulation             8890 non-null   int64
#  72  Simulation Racing      8890 non-null   int64
#  73  Skateboarding          8890 non-null   int64
#  74  Skating                8890 non-null   int64
#  75  Skiing                 8890 non-null   int64
#  76  Snowboarding           8890 non-null   int64
#  77  Sports                 8890 non-null   int64
#  78  Stealth                8890 non-null   int64
#  79  Strategy               8890 non-null   int64
#  80  Surfing                8890 non-null   int64
#  81  Survival               8890 non-null   int64
#  82  Survival Horror        8890 non-null   int64
#  83  Table Tennis           8890 non-null   int64
#  84  Tennis                 8890 non-null   int64
#  85  Third Person Shooter   8890 non-null   int64
#  86  Tower Defence          8890 non-null   int64
#  87  Turn Based             8890 non-null   int64
#  88  Vehicular Combat       8890 non-null   int64
#  89  Visual Novel           8890 non-null   int64
#  90  Volleyball             8890 non-null   int64
#  91  Wrestling              8890 non-null   int64
# dtypes: float64(1), int64(86), object(5)
# memory usage: 6.3+ MB

# %%
#Now that we can split our genres up! Here's the exported csvs for our dataset. One will contain the final clean dataframe.
final_clean_data = final_df.to_csv("CleanedUpData.csv", index = True)
print('\nCSV String:\n', final_clean_data)
# Out:
# CSV String:
#  None
